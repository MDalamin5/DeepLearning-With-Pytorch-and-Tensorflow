# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=15)

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([36.38789703])

# %%
reg.intercept_
# Out:
# -1.314206623292558

# %%
m = 36.38

# %%
class GDRegressor:

    def __init__(self, learning_rate, epochs):
        self.m = 36.38
        self.b = -100
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X, y):
        for i in range(self.epochs):
            lossSlope = -2 * np.sum(y - self.m * X.ravel() - self.b)
            self.b = self.b - (self.lr * lossSlope)
            print(lossSlope, "->",self.b )
        print(self.b)

# %%
gd = GDRegressor(0.001, 40)
gd.fit(X, y)
# Out:
# -19737.087241439123 -> -80.26291275856087
# -15789.669793151294 -> -64.47324296540958
# -12631.735834521038 -> -51.841507130888544
# -10105.38866761683 -> -41.736118463271715
# -8084.310934093464 -> -33.65180752917825
# -6467.4487472747705 -> -27.184358781903477
# -5173.958997819816 -> -22.01039978408366
# -4139.167198255853 -> -17.871232585827805
# -3311.333758604682 -> -14.559898827223122
# -2649.0670068837453 -> -11.910831820339377
# -2119.253605506997 -> -9.79157821483238
# -1695.402884405597 -> -8.096175330426783
# -1356.322307524478 -> -6.739853022902306
# -1085.057846019582 -> -5.654795176882724
# -868.0462768156655 -> -4.786748900067058
# -694.4370214525327 -> -4.092311878614526
# -555.5496171620262 -> -3.5367622614524996
# -444.43969372962084 -> -3.0923225677228787
# -355.55175498369675 -> -2.736770812739182
# -284.4414039869574 -> -2.4523294087522247
# -227.55312318956592 -> -2.2247762855626587
# -182.04249855165273 -> -2.042733787011006
# ...
