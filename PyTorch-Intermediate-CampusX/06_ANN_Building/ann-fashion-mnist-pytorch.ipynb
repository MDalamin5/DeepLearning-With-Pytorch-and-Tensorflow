# %% [markdown]
# # ***Multi class classification Problem and solve by ANN***

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
## Set random deed for reproducibility
torch.manual_seed(42)

# %%
df = pd.read_csv('fmnist_small.csv')
df.sample(5)
# Out:
#       label  pixel1  pixel2  pixel3  ...  pixel781  pixel782  pixel783  pixel784
# 4513      1       0       0       0  ...         0         0         0         0
# 1959      7       0       0       0  ...         0         0         0         0
# 2583      4       0       0       0  ...         0         0         0         0
# 3100      3       0       0       0  ...         0         0         0         0
# 2241      7       0       0       0  ...         0         0         0         0
#
# [5 rows x 785 columns]

# %%
df.shape
# Out:
# (6000, 785)

# %% [markdown]
# ## *See the images data*

# %%
fig, axes = plt.subplots(4, 4, figsize=(10, 10))
fig.suptitle("First 16 images", fontsize=16)

## plt the images
for i, ax in enumerate(axes.flat):
    img = df.iloc[i, 1:].values.reshape(28, 28)
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(f"Label {df.iloc[i, 0]}")
    
    
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
X_train = X_train/255.0
X_test = X_test / 255.0

# %% [markdown]
# ## *Now Create Custom Dataloader class*
